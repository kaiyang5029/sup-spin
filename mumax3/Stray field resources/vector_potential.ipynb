# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
CURRENT_DIRECTORY = os.getcwd()
DATA_AND_LAYER_NAME = "B_demag_125mT_0K_layer2"
DEMAG_B_Z_FILEPATH = os.path.join(CURRENT_DIRECTORY, "stray_field_0K_125mT_128px.out", "%s_z.npy" % DATA_AND_LAYER_NAME)
DEMAG_B_Z = np.load(DEMAG_B_Z_FILEPATH)
APPLIED_B_Z = 0.125

# %%
plt.pcolormesh(B_Z, cmap="viridis")
plt.colorbar()
plt.title("B_z (T) under +125 mT external field")
# Out:
# Text(0.5, 1.0, 'B_z (T) under +125 mT external field')

# %%
B_Z = DEMAG_B_Z + APPLIED_B_Z
plt.pcolormesh(B_Z, cmap="viridis")
plt.colorbar()

# %%
from scipy import interpolate
# Out:
# (128, 128)
